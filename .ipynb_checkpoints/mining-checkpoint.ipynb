# %% [markdown]
# # Importation des librairies

# %%
import nltk
import pandas as pd
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk import bigrams
from nltk.util import ngrams
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
import itertools
import collections
# import re
import networkx as nx
# from nltk.stem import PorterStemmer
# import nltk as nlp
# import string
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\irvin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\irvin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # importation du dataframe

# %%
df = pd.read_csv('caf/articles1.csv')
date_title = pd.DataFrame(data=df.dropna(subset=['pub_date', 'title']), columns=['pub_date', 'title'])

date_title
# Out:
#         pub_date                                              title
# 0     2023-11-09  ChatGPT and other Large Language Models for Cy...
# 1     2023-11-02  Emergent (In)Security of Multi-Cloud Environments
# 2     2023-11-02  A Review of Digital Twins and their Applicatio...
# 3     2023-11-06  Hacking Cryptographic Protocols with Advanced ...
# 4     2023-11-05  The New Frontier of Cybersecurity: Emerging Th...
# ...          ...                                                ...
# 2021  2020-01-01       Cybersecurity risks of blockchain technology
# 2022  2018-01-01  CSIRT s and global cybersecurity: How technica...
# 2023  2019-01-01           Curricular foundations for cybersecurity
# 2024  2019-01-01  CNDS-cybersecurity: issues and challenges in A...
# 2025  2017-01-01  Ciberseguridad. Presentación del dossier/Cyber...
#
# [2001 rows x 2 columns]

# %% [markdown]
# # Nettoyage supplémentaire
# - mise en minuscule
# - retrait des stopwords
# - retrait des ponctuations

# %%
# definition de la langue, des mots à exclure et des ponctuations à exclure
stop = set(stopwords.words("english"))
#punct = set(string.punctuation)
punct = {'!',
 '"',
 '#',
 '$',
 '%',
 '&',
 "'",
 '(',
 ')',
 '*',
 '+',
 ',',
 '.',
 '/',
 ':',
 ';',
 '<',
 '=',
 '>',
 '?',
 '@',
 '[',
 '\\',
 ']',
 '^',
 '`',
 '{',
 '”',
 '--',
  '…',
 '|',
 '}',
 '~'}

# %%
# definition de la fonction de nettoyage
def clean(doc):
    stop_free=" ".join([i for i in doc.lower().split() if i not in stop])
    punct_free=''.join(j for j in stop_free if j not in punct)
    return punct_free

# nettoyage de title et insertion dans la nouvelle colonne cleaned_title
date_title['cleaned_title'] = df['title'].astype(str).apply(clean)
date_title
# cleaned_title = [clean(str(date_title.iloc[i, 1])) for i in range(0, date_title.shape[0])]
# cleaned_title
# Out:
#         pub_date                                              title  \
# 0     2023-11-09  ChatGPT and other Large Language Models for Cy...
# 1     2023-11-02  Emergent (In)Security of Multi-Cloud Environments
# 2     2023-11-02  A Review of Digital Twins and their Applicatio...
# 3     2023-11-06  Hacking Cryptographic Protocols with Advanced ...
# 4     2023-11-05  The New Frontier of Cybersecurity: Emerging Th...
# ...          ...                                                ...
# 2021  2020-01-01       Cybersecurity risks of blockchain technology
# 2022  2018-01-01  CSIRT s and global cybersecurity: How technica...
# 2023  2019-01-01           Curricular foundations for cybersecurity
# 2024  2019-01-01  CNDS-cybersecurity: issues and challenges in A...
# 2025  2017-01-01  Ciberseguridad. Presentación del dossier/Cyber...
#
#                                           cleaned_title
# 0     chatgpt large language models cybersecurity sm...
# 1          emergent insecurity multi-cloud environments
# 2     review digital twins application cybersecurity...
# 3     hacking cryptographic protocols advanced varia...
# 4     new frontier cybersecurity emerging threats in...
# ...                                                 ...
# 2021          cybersecurity risks blockchain technology
# 2022  csirt global cybersecurity technical experts s...
# 2023               curricular foundations cybersecurity
# 2024  cnds-cybersecurity issues challenges asean cou...
# 2025  ciberseguridad presentación del dossiercyberse...
#
# [2001 rows x 3 columns]

# %% [markdown]
# # NLP
# - stemming (abandonné parce que les mots obtenus ne sont pas valides)
# - tokenization + lemmatization

# %%
#stemming
# pst = PorterStemmer()
# date_title['lemmed_title'] = date_title['cleaned_title'].apply(pst.stem)

#lemmatization
def lemmatize_title(text):
    # Tokenizing the text
    tokens = nltk.word_tokenize(text)
    # Lemmatizing each token
    lemmatized_tokens = [nltk.WordNetLemmatizer().lemmatize(token) for token in tokens]
    # Joining the lemmatized tokens into a single string
    lemmatized_text = " ".join(lemmatized_tokens)
    return lemmatized_text

#creating a new column for the lemmatized titles
date_title['lemmatized_title'] = date_title['cleaned_title'].apply(lemmatize_title)

date_title
# Out:
#         pub_date                                              title  \
# 0     2023-11-09  ChatGPT and other Large Language Models for Cy...
# 1     2023-11-02  Emergent (In)Security of Multi-Cloud Environments
# 2     2023-11-02  A Review of Digital Twins and their Applicatio...
# 3     2023-11-06  Hacking Cryptographic Protocols with Advanced ...
# 4     2023-11-05  The New Frontier of Cybersecurity: Emerging Th...
# ...          ...                                                ...
# 2021  2020-01-01       Cybersecurity risks of blockchain technology
# 2022  2018-01-01  CSIRT s and global cybersecurity: How technica...
# 2023  2019-01-01           Curricular foundations for cybersecurity
# 2024  2019-01-01  CNDS-cybersecurity: issues and challenges in A...
# 2025  2017-01-01  Ciberseguridad. Presentación del dossier/Cyber...
#
#                                           cleaned_title  \
# 0     chatgpt large language models cybersecurity sm...
# 1          emergent insecurity multi-cloud environments
# 2     review digital twins application cybersecurity...
# 3     hacking cryptographic protocols advanced varia...
# 4     new frontier cybersecurity emerging threats in...
# ...                                                 ...
# 2021          cybersecurity risks blockchain technology
# 2022  csirt global cybersecurity technical experts s...
# 2023               curricular foundations cybersecurity
# 2024  cnds-cybersecurity issues challenges asean cou...
# 2025  ciberseguridad presentación del dossiercyberse...
#
#                                        lemmatized_title
# 0     chatgpt large language model cybersecurity sma...
# 1           emergent insecurity multi-cloud environment
# 2     review digital twin application cybersecurity ...
# 3     hacking cryptographic protocol advanced variat...
# 4     new frontier cybersecurity emerging threat inn...
# ...                                                 ...
# 2021           cybersecurity risk blockchain technology
# 2022  csirt global cybersecurity technical expert su...
# 2023                curricular foundation cybersecurity
# 2024   cnds-cybersecurity issue challenge asean country
# 2025  ciberseguridad presentación del dossiercyberse...
#
# [2001 rows x 4 columns]

# %%
# Get the list of titles
titles = date_title['lemmatized_title'].tolist()

# Concatenate the titles
concat_titles = " ".join(titles)
concat_titles
# Out:
# 'chatgpt large language model cybersecurity smart grid application emergent insecurity multi-cloud environment review digital twin application cybersecurity based artificial intelligence hacking cryptographic protocol advanced variational quantum attack new frontier cybersecurity emerging threat innovation intell-dragonfly cybersecurity attack surface generation engine based artificial intelligence-generated content technology acwa ai-driven cyber-physical testbed intelligent water system split-ner named entity recognition via two question-answering-based classification artificial intelligence ethic education cybersecurity challenge opportunity focus group report quantum-inspired anomaly detection qubo formulation bit insight exploring network traffic traffic matrix heavy-tailed data unscrambling rectification adversarial attack transferability across computer network ic-secure intelligent system assisting security expert generating playbook automated incident response sok security o -- security analysis uefi mirage multi-binary image risk assessment attack graph employment novel approach attack tree attack graph transformation extended version educating ai cybersecurity work research ethic system thinking communication requirement enhancing malware detection integrating machine learning cuckoo sandbox cybersecurity crosscutting concept across undergrad computer science curriculum experience report qualitative analysis validating iec 62443-4-2 requirement devsecops sentinel aggregation function secure decentralized federated learning network disruption via continuous batch removal case sicilian mafia survey security attack connected autonomous vehicular system white paper cybersecurity healthcare sector heir solution assessing influence different type probing adversarial decision-making deception game electric vehicle aggregation review benefit vulnerability managing growing ev fleet smart omvi obfuscated malware variant identification using novel dataset fast adversarial label-flipping attack tabular data trojan literature survey critical evaluation latest ml based modern intrusion detection system iot environment evaluating llm privilege-escalation scenario charge manipulation attack smart electric vehicle charging station deep learning-based detection mechanism ai potentiality awareness position paper perspective human-ai teaming cybersecurity efficacy transformer-based adversarial attack security domain knowcc knowledge awareness computer cyber ethic csnon-cs university student reward shaping happier autonomous cyber security agent survey data security practice cybersecurity challenge machine learning application deep learning cybersecurity survey quantum key distribution critical infrastructure towards cyber physical security hydropower dam survey detection llms-generated content empowering distributed solution renewable energy system grid optimization comprehensive python library deep learning-based event detection multivariate time series data information retrieval nlp survey network requirement enabling effective cyber deception unified taxonomy evaluation iot security guideline risk threat mitigation technique internet thing iot environment survey threat modelling internet thing iot environment using dynamic attack graph key deobfuscation pattern life overcoming encryption cymed framework testing cybersecurity connected medical device cybersecurity dynamic foundation science cybersecurity cybersecurity health care decoding threat landscape chatgpt fraudgpt wormgpt social engineering attack red teaming generative ainlp bb84 quantum cryptography protocol nist-approved quantum-resistant cryptographic algorithm comparative analysis imbalanced malware byteplot image classification using transfer learning comparing ai algorithm optimizing elliptic curve cryptography parameter third-party e-commerce integration pre-quantum era analysis huntgpt integrating machine learning-based anomaly detection explainable ai large language ...

# %% [markdown]
# # Analyse
# - faire ressortir les mots uniques
# - frequence des mots
# - evolution du nombre d'article sur la cybersecurite par annee
# - frequence des mots sur chaque année (trend analysis)

# %%
# Split the titles into words
words = concat_titles.split()

# Count the number of occurrences of each word
word_counts = FreqDist(words)
word_counts
# Out:
# FreqDist({'cybersecurity': 1214, 'learning': 215, 'system': 169, 'detection': 167, 'security': 148, 'attack': 137, 'risk': 122, 'network': 118, 'cyber': 115, 'using': 113, ...})

# %%
#creating a dataframe for the different words in all the dataset
freq = pd.DataFrame(word_counts.items(), columns=['word', 'frequence']).sort_values(by='frequence', ascending=False)
freq.to_csv('frequence_all_words.csv', index=False)
freq
# Out:
#                word  frequence
# 4     cybersecurity       1214
# 116        learning        215
# 43           system        169
# 61        detection        167
# 80         security        148
# ...             ...        ...
# 1649    honeytokens          1
# 1648      revisited          1
# 1646        stacked          1
# 1645      two-stage          1
# 3243        dossier          1
#
# [3244 rows x 2 columns]

# %%
#retrieving the top 100 words
top = pd.DataFrame(data=freq.head(100))#.reset_index(drop=True)
top.to_csv('top_100_all_words.csv', index=False)
top
# Out:
#               word  frequence
# 4    cybersecurity       1214
# 116       learning        215
# 43          system        169
# 61       detection        167
# 80        security        148
# ..             ...        ...
# 122        science         21
# 208      knowledge         21
# 598         design         21
# 343     blockchain         21
# 217       practice         21
#
# [100 rows x 2 columns]

# %%
top.head(25).plot(kind='bar', x='word')
# Out:
# <Axes: xlabel='word'>

# %%
#getting the years
year = pd.to_datetime(date_title["pub_date"]).dt.year
year
# Out:
# 0       2023
# 1       2023
# 2       2023
# 3       2023
# 4       2023
#         ...
# 2021    2020
# 2022    2018
# 2023    2019
# 2024    2019
# 2025    2017
# Name: pub_date, Length: 2001, dtype: int32

# %%
#the number of articles about cybersecurity each year
article_number = year.value_counts()
article_number.to_csv('acticle_number_by_year.csv')
article_number
# Out:
# pub_date
# 2021    374
# 2023    334
# 2022    325
# 2020    270
# 2019    208
# 2018    150
# 2017    104
# 2016     59
# 2015     45
# 2014     36
# 2011     22
# 2013     21
# 2012     16
# 2010     12
# 2009      8
# 2005      6
# 2008      6
# 2003      3
# 2002      1
# 2007      1
# Name: count, dtype: int64

# %%
article_number.sort_index(ascending=False).plot(kind='bar', x='pub_date')
# Out:
# <Axes: xlabel='pub_date'>

# %% [markdown]
# ### pourquoi y a t'il un pic en 2021 ?
# - de plus : " La durée moyenne de publication d'un article scientifique varie en fonction de plusieurs facteurs, tels que le domaine de recherche, la revue dans laquelle l'article est soumis, et la qualité de l'article. En général, la durée moyenne de publication est d'environ 12 à 18 mois."
# - les articles inspirés par le nombre records de cyber attaques en 2018 dus à la pandémie de covid n'ont pu être publiés qu'au cours de l'année 2021 (en prenant en compte le temps d'écriture de l'article)

# %% [markdown]
# # le word cloud

# %%
#plot wordcloud
wordcloud= WordCloud(width=1000,height=500, stopwords=STOPWORDS, background_color='white').generate(''.join(date_title['lemmatized_title']))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### PLUS DE DONNEES

# %%
# adding the year columns in the dataframe
date_title['year'] = pd.to_datetime(date_title['pub_date']).dt.year
date_title.to_csv('final_data_frame.csv', index=False)
date_title
# Out:
#         pub_date                                              title  \
# 0     2023-11-09  ChatGPT and other Large Language Models for Cy...
# 1     2023-11-02  Emergent (In)Security of Multi-Cloud Environments
# 2     2023-11-02  A Review of Digital Twins and their Applicatio...
# 3     2023-11-06  Hacking Cryptographic Protocols with Advanced ...
# 4     2023-11-05  The New Frontier of Cybersecurity: Emerging Th...
# ...          ...                                                ...
# 2021  2020-01-01       Cybersecurity risks of blockchain technology
# 2022  2018-01-01  CSIRT s and global cybersecurity: How technica...
# 2023  2019-01-01           Curricular foundations for cybersecurity
# 2024  2019-01-01  CNDS-cybersecurity: issues and challenges in A...
# 2025  2017-01-01  Ciberseguridad. Presentación del dossier/Cyber...
#
#                                           cleaned_title  \
# 0     chatgpt large language models cybersecurity sm...
# 1          emergent insecurity multi-cloud environments
# 2     review digital twins application cybersecurity...
# 3     hacking cryptographic protocols advanced varia...
# 4     new frontier cybersecurity emerging threats in...
# ...                                                 ...
# 2021          cybersecurity risks blockchain technology
# 2022  csirt global cybersecurity technical experts s...
# 2023               curricular foundations cybersecurity
# 2024  cnds-cybersecurity issues challenges asean cou...
# 2025  ciberseguridad presentación del dossiercyberse...
#
#                                        lemmatized_title  year
# 0     chatgpt large language model cybersecurity sma...  2023
# 1           emergent insecurity multi-cloud environment  2023
# 2     review digital twin application cybersecurity ...  2023
# 3     hacking cryptographic protocol advanced variat...  2023
# 4     new frontier cybersecurity emerging threat inn...  2023
# ...                                                 ...   ...
# 2021           cybersecurity risk blockchain technology  2020
# 2022  csirt global cybersecurity technical expert su...  2018
# 2023                curricular foundation cybersecurity  2019
# 2024   cnds-cybersecurity issue challenge asean country  2019
# 2025  ciberseguridad presentación del dossiercyberse...  2017
#
# [2001 rows x 5 columns]

# %%
def concat_titles(row):
    return " ".join(row["lemmatized_title"])

group_title_by_year = date_title.groupby("year").apply(concat_titles).squeeze()
group_title_by_year = group_title_by_year.to_frame()
group_title_by_year = group_title_by_year.reset_index(level=0)
group_title_by_year.columns = ["year", "title"]
# group_title_by_year = pd.DataFrame({group_title_by_year})
group_title_by_year
# Out:
#     year                                              title
# 0   2002  issue cybersecurity understanding potential ri...
# 1   2003  securing henp computing facility least effort ...
# 2   2005  creating national framework cybersecurity anal...
# 3   2007  framework linking cybersecurity metric modelin...
# 4   2008  cybersecurity challenge cybersecurity strategy...
# 5   2009  approach solving cybercrime cybersecurity road...
# 6   2010  economics cybersecurity principle policy optio...
# 7   2011  doctrine cybersecurity guideline usable cybers...
# 8   2012  cybersecurity risk cybersecurity new challenge...
# 9   2013  executive order -- improving critical infrastr...
# 10  2014  cybersecurity health care schrodinger cybersec...
# 11  2015  physical security cybersecurity cybersecurity ...
# 12  2016  data mining machine learning cybersecurity con...
# 13  2017  cybersecurity healthcare safe we gender differ...
# 14  2018  global cybersecurity new direction theory meth...
# 15  2019  application deep learning cybersecurity survey...
# 16  2020  social cybersecurity emerging science ethic cy...
# 17  2021  novel approach attack tree attack graph transf...
# 18  2022  ai-assisted authentication state art taxonomy ...
# 19  2023  chatgpt large language model cybersecurity sma...

# %%
#how to get yhe year of a group of title
group_title_by_year.iloc[2,0]
# Out:
# 2005

# %%
#how to get a list of word and frequences from a year
FreqDist(str(group_title_by_year.iloc[4,1]).split())
# Out:
# FreqDist({'cybersecurity': 6, 'assessment': 2, 'research': 2, 'challenge': 1, 'strategy': 1, 'query': 1, 'methodology': 1, 'vulnerability': 1, 'scada': 1, 'system': 1, ...})

# %%
#now the process of storing a word, it's frequence, and the year he appeared
#creating a dataframe
frequences_grouped_by_year = pd.DataFrame()
#initializing 3 empty list
L1=[]
L2=[]
L3=[]
for i in range(group_title_by_year.shape[0]):
        var1 = FreqDist(str(group_title_by_year.iloc[i,1]).split())
        col1 = list(var1.keys())
        L1.extend(col1)
        col2 = list(var1.values())
        L2.extend(col2)
        col3 = group_title_by_year.iloc[i,0]
        L3.extend([col3] * (len(col1)))
frequences_grouped_by_year["word"] = L1
frequences_grouped_by_year["frequence"] = L2
frequences_grouped_by_year["year"] = L3

frequences_grouped_by_year.to_csv('frequence_of_each_word_by_year.csv', index=False)
frequences_grouped_by_year
# Out:
#                word  frequence  year
# 0             issue          1  2002
# 1     cybersecurity          1  2002
# 2     understanding          1  2002
# 3         potential          1  2002
# 4              risk          1  2002
# ...             ...        ...   ...
# 6610      epistemic          1  2023
# 6611      authority          1  2023
# 6612            gap          1  2023
# 6613          child          1  2023
# 6614         medium          1  2023
#
# [6615 rows x 3 columns]

# %% [markdown]
# ### ETUDE DE CO OCCURENCE

# %%
#fonction pour faire une liste avec chaque titre
def get_words(sentence, stop):
    words = set(sentence.split(' '))
    words = list(words-set(stop))
    if '' in words:
        words.remove('')
    return list(words)

# %%
#mettre toutes les listes de titres dans une grande liste
all_titles = date_title['lemmatized_title'].values.tolist()
list_of_titles = []
for each_title in all_titles:
    each_title = clean(each_title)
    list_of_titles.append(get_words(each_title, stop))

# %%
#faire ressortir les paires de mots, les transformer en liste et les mettre dans une grande liste
word_pairs = []
for words in list_of_titles:
    words_ = list(set(words))
    for i in range(len(words_)-1):
        for j in range(i+1, len(words_)):
            word_i = words_[i]
            word_j = words_[j]
            if word_i < word_j:
                word_pairs.append([word_i, word_j])
            else:
                word_pairs.append([word_i, word_j])

# %%
#compter les paires de mots et prendre les 50 qui se répètent le plus
df_word_pairs = pd.DataFrame(data = word_pairs, columns=['word1', 'word2'])
word_pairs_count = df_word_pairs.groupby(['word1', 'word2']).size()
word_pairs_count = word_pairs_count.sort_values().tail(50).reset_index()

# %%
word_pairs_count
# Out:
#             word1         word2   0
# 0   cybersecurity            ai  23
# 1   cybersecurity      internet  24
# 2   cybersecurity       control  24
# 3       detection         using  24
# 4   cybersecurity       network  25
# 5   cybersecurity    management  26
# 6        learning        system  26
# 7   cybersecurity    systematic  26
# 8          neural       network  27
# 9       detection          deep  27
# 10  cybersecurity         issue  27
# 11  cybersecurity          deep  28
# 12  cybersecurity      training  29
# 13  cybersecurity      security  29
# 14  cybersecurity   perspective  29
# 15      intrusion     detection  29
# 16  cybersecurity     detection  30
# 17  cybersecurity         study  30
# 18  cybersecurity         smart  31
# 19        network     detection  32
# 20  cybersecurity   information  33
# 21  cybersecurity      research  33
# 22      detection        system  34
# 23  cybersecurity    artificial  35
# 24  cybersecurity    assessment  37
# 25  cybersecurity   application  37
# 26      detection       anomaly  38
# 27  cybersecurity        future  38
# 28  cybersecurity         model  39
# 29          thing      internet  39
# 30  cybersecurity          data  40
# 31  cybersecurity     education  40
# 32  cybersecurity  intelligence  42
# 33     artificial  intelligence  43
# 34  cybersecurity         using  44
# 35  cybersecurity       machine  45
# 36  cybersecurity      analysis  45
# 37  cybersecurity      approach  48
# 38  cybersecurity        survey  48
# 39       learning     detection  48
# 40  cybersecurity        threat  50
# 41  cybersecurity     awareness  51
# 42       learning          deep  54
# 43  cybersecurity     framework  65
# 44  cybersecurity        system  78
# 45  cybersecurity        review  79
# 46  cybersecurity     challenge  84
# 47        machine      learning  84
# 48  cybersecurity          risk  85
# 49  cybersecurity      learning  91

# %%
# la partie suivante est extraite de : https://www.kaggle.com/code/xxxxyyyy80008/analyze-co-occurrence-and-networks-of-words
# elle nous permet de visualiser la correlation entre les mots

# %%
# Create list of lists containing bigrams
terms_bigram = [list(bigrams(words)) for words in list_of_titles]

# View bigrams for the first assay
print('View bigrams for the first assay')
print(terms_bigram[0][:5])

# Flatten list of bigrams in clean text
bigram_list = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigram_list)

bigram_counts.most_common(5)
# Out:
# View bigrams for the first assay
# [('cybersecurity', 'application'), ('application', 'model'), ('model', 'large'), ('large', 'grid'), ('grid', 'chatgpt')]
# [(('machine', 'learning'), 35),
#  (('cybersecurity', 'review'), 31),
#  (('intrusion', 'detection'), 23),
#  (('detection', 'system'), 23),
#  (('assessment', 'risk'), 21)]

# %%
# Create list of lists containing bigrams
terms_3gram = [list(ngrams(words, 4)) for words in list_of_titles]

# View bigrams for the first assay
print('View N-grams (N=3) for the first assay')
print(terms_3gram[0][:5])


gram3_list = list(itertools.chain(*terms_3gram))

# Create counter of words in clean bigrams
gram3_counts = collections.Counter(gram3_list)

pd.DataFrame(gram3_counts.most_common(25), columns=['enchainement', 'nombre de repetitions']).to_csv('enchainement_les_plus_presents.csv', index=False)
gram3_counts.most_common(25)
# Out:
# View N-grams (N=3) for the first assay
# [('cybersecurity', 'application', 'model', 'large'), ('application', 'model', 'large', 'grid'), ('model', 'large', 'grid', 'chatgpt'), ('large', 'grid', 'chatgpt', 'smart'), ('grid', 'chatgpt', 'smart', 'language')]
# [(('cybersecurity', 'improving', 'infrastructure', 'critical'), 4),
#  (('learning', 'detection', 'intrusion', 'system'), 3),
#  (('improving', 'infrastructure', 'critical', 'framework'), 3),
#  (('learning', 'intrusion', 'detection', 'system'), 3),
#  (('cybersecurity', 'review', 'machine', 'learning'), 3),
#  (('cybersecurity', 'grid', 'smart', 'survey'), 3),
#  (('cybersecurity', 'foundation', 'dynamic', 'science'), 2),
#  (('learning', 'network', 'intrusion', 'detection'), 2),
#  (('network', 'intrusion', 'detection', 'system'), 2),
#  (('cybersecurity', 'impact', 'ai', 'chatgpt'), 2),
#  (('impact', 'ai', 'chatgpt', 'threatgpt'), 2),
#  (('ai', 'chatgpt', 'threatgpt', 'privacy'), 2),
#  (('chatgpt', 'threatgpt', 'privacy', 'generative'), 2),
#  (('cybersecurity', 'policy', 'principle', 'option'), 2),
#  (('policy', 'principle', 'option', 'economics'), 2),
#  (('network', 'detection', 'intrusion', 'system'), 2),
#  (('cybersecurity', 'artificial', 'survey', 'explainable'), 2),
#  (('artificial', 'survey', 'explainable', 'intelligence'), 2),
#  (('cybersecurity', 'workforce', 'ai', 'next'), 2),
#  (('workforce', 'ai', 'next', 'generation'), 2),
#  (('architecture', 'recurrent', 'network', 'litelstm'), 2),
#  (('learning', 'detection', 'using', 'malicious'), 2),
#  (('machine', 'survey', 'comprehensive', 'detection'), 2),
#  (('cybersecurity', 'machine', 'role', 'learning'), 2),
#  (('cybersecurity', 'future', 'present', 'past'), 2)]

# %% [markdown]
# ### Visualize Networks of Bigrams and Co-occur Pairs

# %%
# Create network plot
G = nx.Graph()


for _, row in word_pairs_count.iterrows():
    G.add_edge(row['word1'], row['word2'], weight=row[0])

# %%
pos_kkl = nx.kamada_kawai_layout(G)
f, ax = plt.subplots(figsize=(16, 16))


d = dict(nx.degree(G))
edges = G.edges()
weights = [G[u][v]['weight']/1000 for u,v in edges]

nx.draw(G, pos_kkl,
        with_labels=True,
        node_size=[v * 100 for v in d.values()],
        nodelist=d.keys(),
        width=weights,
        edge_color='grey', #node_color=list(df_skills_stats['core_number']), cmap="coolwarm_r",
        alpha=0.9,
       )
#node_labels = nx.draw_networkx_labels(G, pos_kkl, labels, font_size=10)
# Set title
ax.set_title('réseau de co-ocurence des mots',
             fontdict={'fontsize': 26,
            'fontweight': 'bold',
            'color': 'salmon',
            'verticalalignment': 'baseline',
            'horizontalalignment': 'center'},
             loc='center')
# Set edge color
plt.gca().collections[0].set_edgecolor("#000000")

# %%
# Create network plot
G = nx.Graph()

# Create connections between nodes
for v in bigram_counts.most_common(30):
    G.add_edge(v[0][0], v[0][1], weight=(v[1] * 10))

# %%
fig, ax = plt.subplots(figsize=(18, 10))

pos = nx.spring_layout(G, k=8)

d = dict(nx.degree(G))
edges = G.edges()
weights = [G[u][v]['weight']/1000 for u,v in edges]
# Plot networks
nx.draw_networkx(G, pos,
                 font_size=16,
                 width=weights,
                 node_size = [v * 200 for v in d.values()],
                 edge_color='grey',
                 #node_color='tomato',
                 with_labels = True,
                 ax=ax)

ax.set_title('Réseau bigramme',
             fontdict={'fontsize': 26,
            'fontweight': 'bold',
            'color': 'salmon',
            'verticalalignment': 'baseline',
            'horizontalalignment': 'center'},
             loc='center')
plt.show()
